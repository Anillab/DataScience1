# %% [markdown]
# # Module 1: Introduction to Exploratory Analysis

# %% [markdown]
# What we'll be doing in this notebook:
# -----
#
#  1.  Checking variable type
#  2.  Checking for missing variables
#  3.  Number of observations in the dataset
#  4.  Descriptive statistics

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser

# The command below means that the output of multiple commands in a cell will be output at once
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# The command below tells jupyter to display up to 80 columns, this keeps everything visible
pd.set_option('display.max_columns', 80)
pd.set_option('expand_frame_repr', True)

# Show figures in notebook
# %matplotlib inline

# %% [markdown]
# ### Import dataset

# %% [markdown]
# We read in our dataset

# %%
kiva_locations = pd.read_csv("/home/anilla/DataScience/DataScience1/data/Kenya/kiva_ke_locations.csv")
kiva_loans=pd.read_csv("/home/anilla/DataScience/DataScience1/data/Kenya/kiva_loans_ke.csv")
loan_theme=pd.read_csv("/home/anilla/DataScience/DataScience1/data/Kenya/loan_theme_ke.csv")

# %% [markdown]
# In the cell below, we take a random sample of 2 rows to get a feel for the data.

# %%
kiva_loans.sample(n=102)
# Out:
#             id  funded_amount  loan_amount               activity  \
# 3357    681643            250          250                   Food
# 65961  1235075            500          500    Fruits & Vegetables
# 8093    729244            175          175           Fish Selling
# 49024  1056381            200          200  Food Production/Sales
# 71463  1285766            500          500     Water Distribution
# 4      1080150            125          125                 Energy
# 60518  1191997            675          675                Farming
# 650     659059            600          600                   Food
# 56448  1150170            500          500                 Retail
# 17988   805187           1275         1275                Farming
# 28918   885415             75          625             Restaurant
# 34186   927122            675          800               Services
# 20762   826912            225          225                Farming
# 68513  1260127            500          500          General Store
# 41997  1001867            100          100    Fruits & Vegetables
# 29438   888996            225          225       Furniture Making
# 4497    692863           1225         1225                Farming
# 65458  1230950            100          100          General Store
# 22347  1087379            100          100          Grocery Store
# 15691  1085153            125          125               Services
# 28289   879904            325          325                Farming
# 46560  1036527            475         1025                Farming
# 61454  1199020            925          925                Farming
# 60829  1195554            325          400           Fish Selling
# 13475   777336            125          125                Farming
# 2185    671876            475          475                Cereals
# 24266   853080            675          675                Farming
# 24174   852990            275          275                  Dairy
# 50542  1074394            300          300                Farming
# 75448  1332065            125          300                Farming
# ...        ...            ...          ...                    ...
# 13130   774891            575          575         Clothing Sales
# 54316  1129099            500          500             Metal Shop
# 49745  1065606            400          400    Fruits & Vegetables
# 50534  1074581            300          300                 Bakery
# 58818  1178620            500          500    Home Products Sales
# 46027  1032044            725          725                Farming
# 13204   775302            450          450              Tailoring
# 46059  1031966            700          950               Services
# 36779   947308            475          475                Farming
# 49219  1058710            100          100                Farming
# 24897   856653            175          175    Fruits & Vegetables
# 56862  1155186            400          400          General Store
# 66642  1242796            100          100                Farming
# 27556   874772            700          700            Agriculture
# 72172  1293306            400          400          General Store
# 10325   753807           1025         1025                  Dairy
# 20119   822563           1350         1350                 Health
# 27592  1088539            125          125          Grocery Store
# 22362   838463            675          675                Farming
# 52728  1111014            200          200          General Store
# 46811  1038047            650          650                Cereals
# 74545  1320286              0         1475               Hardware
# 27455   874622            275          275                Farming
# 50961  1091351            200          800            Electrician
# 4478   1080905            375          375          Grocery Store
# 55532  1140333            300          300       Electrical Goods
# 54794  1133178            500          500                Farming
#
#       country_code country          region currency  partner_id  \
# 3357            KE   Kenya         Mombasa      KES       138.0
# 65961           KE   Kenya           Busia      KES       138.0
# 8093            KE   Kenya          Tiribe      KES       164.0
# 49024           KE   Kenya      Mwambalazi      KES       164.0
# 71463           KE   Kenya          Likoni      KES       164.0
# 4               KE   Kenya             NaN      KES         NaN
# 60518           KE   Kenya         Sirisia      KES       202.0
# 650             KE   Kenya         Kericho      KES       138.0
# 56448           KE   Kenya            Maua      KES       138.0
# 17988           KE   Kenya             NaN      KES       202.0
# 28918           KE   Kenya        Machakos      KES       133.0
# 34186           KE   Kenya          Nakuru      KES       138.0
# 20762           KE   Kenya        Kerugoya      KES       156.0
# 68513           KE   Kenya       Changamwe      KES       164.0
# 41997           KE   Kenya           Ngara      KES       138.0
# 29438           KE   Kenya           Thika      KES       388.0
# 4497            KE   Kenya       Nyahururu      KES       133.0
# 65458           KE   Kenya          Nakuru      KES       138.0
# 22347           KE   Kenya             NaN      KES         NaN
# 15691           KE   Kenya             NaN      KES         NaN
# 28289           KE   Kenya        Ndaragwa      KES       156.0
# 46560           KE   Kenya            Teso      KES       202.0
# 61454           KE   Kenya          Matete      KES       202.0
# 60829           KE   Kenya          Kisumu      KES       386.0
# 13475           KE   Kenya          Limuru      KES       388.0
# 2185            KE   Kenya          Tiribe      KES       164.0
# 24266           KE   Kenya  Kakamega North      KES       202.0
# 24174           KE   Kenya           Kisii      KES       133.0
# 50542           KE   Kenya           Nkubu      KES       156.0
# 75448           KE   Kenya         Eldoret      KES       156.0
# ...            ...     ...             ...      ...         ...
# 13130           KE   Kenya          Likoni      KES       164.0
# 54316           KE   Kenya           Narok      KES       386.0
# 49745           KE   Kenya          Taveta      KES       138.0
# 50534           KE   Kenya         Kericho      KES       386.0
# 58818           KE   Kenya           Bomet      KES       386.0
# 46027           KE   Kenya          Chwele      KES       202.0
# 13204           KE   Kenya        Kaloleni      KES       164.0
# 46059           KE   Kenya         Bungoma      KES       138.0
# 36779           KE   Kenya          Kilifi      KES       138.0
# 49219           KE   Kenya     Nakuru West      KES       388.0
# 24897           KE   Kenya             Voi      KES       133.0
# 56862           KE   Kenya          Taveta      KES       138.0
# 66642           KE   Kenya          Kitale      KES       138.0
# 27556           KE   Kenya         Matete-      KES       202.0
# 72172           KE   Kenya         Mombasa      KES       138.0
# 10325           KE   Kenya          Kiambu      KES       386.0
# 20119           KE   Kenya          NDHIWA      USD       324.0
# 27592           KE   Kenya             NaN      KES         NaN
# 22362           KE   Kenya           Chuka      KES       156.0
# 52728           KE   Kenya       Mikinduri      KES       164.0
# 46811           KE   Kenya     Nandi Hills      KES       156.0
# 74545           KE   Kenya           Busia      KES       138.0
# 27455           KE   Kenya           Kisii      KES       133.0
# 50961           KE   Kenya         Kericho      KES       386.0
# 4478            KE   Kenya             NaN      KES         NaN
# 55532           KE   Kenya       Mariakani      KES       133.0
# 54794           KE   Kenya          Kitale      KES       156.0
# 75211           KE   Kenya        Kerugoya      KES       156.0
# 12558           KE   Kenya          Nakuru      KES       138.0
# 69139           KE   Kenya          Kitale      KES       156.0
#
#                      posted_time             disbursed_time  \
# 50534  2016-06-09 17:37:03+00:00              14            11
# 58818  2016-12-11 13:14:26+00:00              11            14
# 46027  2016-03-27 16:37:37+00:00              11            27
# 13204  2014-10-01 07:01:05+00:00              13            18
# 46059                        NaN              14            14
# 36779  2015-09-24 19:45:20+00:00              14            19
# 49219  2016-04-26 21:41:50+00:00              14             1
# 24897  2015-03-22 13:23:09+00:00               8             7
# 56862  2016-10-25 17:29:25+00:00              14            15
# 66642  2017-02-26 17:07:32+00:00               8             4
# 27556  2015-05-29 15:38:12+00:00              10            20
# 72172  2017-06-07 16:07:55+00:00              14             9
# 10325  2014-08-30 20:28:09+00:00              15            36
# 20119  2014-12-31 18:25:31+00:00              73            37
# 27592  2015-05-14 05:40:38+00:00               2            13
# 22362  2015-02-18 14:31:08+00:00              16            26
# 52728  2016-07-19 06:34:06+00:00              14             6
# 46811  2016-04-11 19:15:34+00:00              20            21
# 74545                        NaN              14             0
# 27455  2015-05-07 20:16:48+00:00              12            10
# 50961                        NaN              14             8
# 4478   2014-04-04 02:28:08+00:00               9             3
# 55532  2016-09-26 12:16:41+00:00              14            10
# 54794  2016-09-14 16:19:06+00:00              14            16
# 75211                        NaN              14             0
# 12558  2014-10-01 04:37:13+00:00              14             5
# 69139  2017-04-27 13:58:17+00:00              20            13
#
#                                                     tags  \
# 3357              #First Loan, #Parent, #Woman Owned Biz
# 65961  #Woman Owned Biz, #Repeat Borrower, #Vegan, us...
# 8093                                       user_favorite
# 49024                          #Parent, #Woman Owned Biz
# 71463           #Parent, #Woman Owned Biz, user_favorite
# 4                                                    NaN
# 60518  #Sustainable Ag, #Eco-friendly, #Schooling, #E...
# 650             #Woman Owned Biz, #Vegan, #Single Parent
# 56448  #Woman Owned Biz, #Parent, #First Loan, #Schoo...
# 17988                                      user_favorite
# 28918                #Elderly, #Parent, #Repeat Borrower
# 34186             #Repeat Borrower, #Technology, #Parent
# 20762  #Animals, #Vegan, #Parent, #Inspiring Story, #...
# 68513                  #Parent, #Woman Owned Biz, #Vegan
# 41997  volunteer_pick, #Repeat Borrower, #Parent, #Vegan
# 29438                                                NaN
# 4497   user_favorite, #Biz Durable Asset, #Parent, #R...
# 65458          volunteer_pick, #Parent, #Woman Owned Biz
# 22347                                                NaN
# 15691                                                NaN
# 28289                                      user_favorite
# 46560  #Eco-friendly, #Sustainable Ag, #Technology, #...
# 61454  #Sustainable Ag, #Eco-friendly, #Parent, #Tech...
# 60829  #Single, #Supporting Family, #Repeat Borrower,...
# 13475                                                NaN
# 2185   #Fabrics, #Schooling, #Vegan, #First Loan, #Wo...
# 24266  #Eco-friendly, #Woman Owned Biz, #Vegan, #Tech...
# 24174           #Animals, #Elderly, #First Loan, #Parent
# 50542                          #Schooling, user_favorite
# 75448                                                NaN
# ...                                                  ...
# 13130                          #Woman Owned Biz, #Parent
# 54316      #Elderly, #Parent, #First Loan, user_favorite
# 49745                                                NaN
# 50534                          #Repeat Borrower, #Parent
# 58818  #Parent, #Woman Owned Biz, #Eco-friendly, #Fir...
# 46027  #Eco-friendly, #Sustainable Ag, #Technology, #...
# 13204                                      user_favorite
# 46059      #Repeat Borrower, #Parent, #Biz Durable Asset
# 36779  user_favorite, #Repeat Borrower, #Parent, #Veg...
# 49219                                         #Schooling
# 24897                                                NaN
# 56862        #Woman Owned Biz, #Parent, #Repeat Borrower
# 66642                          #Parent, #Woman Owned Biz
# 27556  #Elderly, #Eco-friendly, #Sustainable Ag, #Veg...
# 72172                                   #Woman Owned Biz
# 10325                                                NaN
# 20119                                                NaN
# 27592                                                NaN
# 22362  #Animals, #Single Parent, #Schooling, #Woman O...
# 52728                          #Parent, #Woman Owned Biz
# 46811                                            #Parent
# 74545        #Parent, #Repeat Borrower, #Woman Owned Biz
# 27455  #Elderly, #Animals, #Parent, #Schooling, #Biz ...
# 50961                        #Parent, #Biz Durable Asset
# 4478                                                 NaN
# 55532             #Technology, #Parent, #Repeat Borrower
# 54794                          #Repeat Borrower, #Parent
# 75211                          #Parent, #Woman Owned Biz
# 12558  #Parent, #Repeat Borrower, #Vegan, #Woman Owne...
# 69139              #Woman Owned Biz, #Parent, #Schooling
#
#                                         borrower_genders repayment_interval  \
# 3357                                              female            monthly
# 65961                                             female            monthly
# 8093                                              female          irregular
# 49024                                             female          irregular
# 71463                                             female          irregular
# 4                                                   male          irregular
# 60518       male, female, male, male, female, male, male             bullet
# 650                                               female            monthly
# 56448                                             female            monthly
# 17988                                                NaN             bullet
# 28918                                               male            monthly
# 34186                                             female            monthly
# 20762                                             female            monthly
# 68513                                             female          irregular
# 41997                                               male            monthly
# 29438                                               male            monthly
# 4497                                                male            monthly
# 65458                                             female            monthly
# 22347                                             female             weekly
# 15691                                             female          irregular
# 28289                                               male            monthly
# 46560  male, male, male, male, female, male, male, ma...             bullet
# 61454  female, male, female, male, female, male, fema...             bullet
# 60829                                               male          irregular
# 13475                                               male            monthly
# 2185                                              female          irregular
# 24266         male, female, female, female, male, female             bullet
# 24174                                               male            monthly
# 50542                                             female            monthly
# 75448                                             female            monthly
# ...                                                  ...                ...
# 13130                                             female          irregular
# 54316                                               male          irregular
# 49745                                             female            monthly
# 50534                                               male          irregular
# 58818                                             female          irregular
# 46027  male, female, female, male, male, male, male, ...             bullet
# 13204                                             female          irregular
# 46059                                               male            monthly
# 36779                                             female            monthly
# 49219                                             female            monthly
# 24897                                             female            monthly
# 56862                                             female            monthly
# 66642                                             female            monthly
# 27556  female, female, female, female, female, female...             bullet
# 72172                                             female            monthly
# 10325                                             female          irregular
# 20119                               male, female, female          irregular
# 27592                                             female             weekly
# 22362                                             female            monthly
# 52728                                             female          irregular
# 46811                                             female            monthly
# 74545                                             female            monthly
# 27455                                               male            monthly
# 50961                                               male          irregular
# 4478                                              female          irregular
# 55532                                               male            monthly
# 54794                                             female            monthly
# 75211                                             female            monthly
# 12558                                             female            monthly
# 69139                                             female            monthly
#
#              date
# 3357   2014-03-11
# 65961  2017-02-09
# 8093   2014-06-23
# 49024  2016-04-19
# 71463  2017-04-25
# 4      2014-01-02
# 60518  2016-11-24
# 650    2014-01-18
# 56448  2016-09-14
# 17988  2014-11-25
# 28918  2015-05-14
# 34186  2015-08-03
# 20762  2015-01-12
# 68513  2017-03-17
# 41997  2015-12-29
# 29438  2015-05-21
# 4497   2014-04-03
# 65458  2017-02-02
# 22347  2015-02-10
# 15691  2014-11-01
# 28289  2015-05-05
# 46560  2016-03-10
# 61454  2016-12-06
# 60829  2016-11-29
# 13475  2014-10-01
# 2185   2014-02-18
# 24266  2015-03-10
# 24174  2015-03-10
# 50542  2016-05-24
# 75448  2017-07-03
# ...           ...
# 13130  2014-09-25
# 54316  2016-08-04
# 49745  2016-05-06
# 50534  2016-05-24
# 58818  2016-11-02
# 46027  2016-03-02
# 13204  2014-09-26
# 46059  2016-03-02
# 36779  2015-09-14
# 49219  2016-04-22
# 24897  2015-03-17
# 56862  2016-09-22
# 66642  2017-02-21
# 27556  2015-04-23
# 72172  2017-05-05
# 10325  2014-08-13
# 20119  2014-12-30
# 27592  2015-04-24
# 22362  2015-02-10
# 52728  2016-07-04
# 46811  2016-03-14
# 74545  2017-06-15
# 27455  2015-04-23
# 50961  2016-05-30
# 4478   2014-04-03
# 55532  2016-08-26
# 54794  2016-08-15
# 75211  2017-06-29
# 12558  2014-09-18
# 69139  2017-03-23
#
# [102 rows x 20 columns]

# %% [markdown]
# ### 1) Type Checking
# <a id='type_check'></a>

# %% [markdown]
# Type is very important in Python programing, because it affects the types of functions you can apply to a series. There are a few different types of data you will see regularly (see [this](https://en.wikibooks.org/wiki/Python_Programming/Data_Types) link for more detail):
# * **int** - a number with no decimal places. example: loan_amount field
# * **float** - a number with decimal places. example: partner_id field
# * **str** - str is short for string. This type formally defined as a sequence of unicode characters. More simply, string means that the data is treated as a word, not a number. example: sector
# * **boolean** - can only be True or False. There is not currently an example in the data, but we will be creating a gender field shortly.
# * **datetime** - values meant to hold time data. Example: posted_date
#
# Let's check the type of our variables using the examples we saw in the cell above.

# %%
# Here are all of the columns
kiva_loans.columns.tolist()
# Out:
# ['id',
#  'funded_amount',
#  'loan_amount',
#  'activity',
#  'sector',
#  'use',
#  'country_code',
#  'country',
#  'region',
#  'currency',
#  'partner_id',
#  'posted_time',
#  'disbursed_time',
#  'funded_time',
#  'term_in_months',
#  'lender_count',
#  'tags',
#  'borrower_genders',
#  'repayment_interval',
#  'date']

# %%
# Find the dtype, aka datatype, for a column
df['id_number'].dtype
# Out:
# dtype('int64')

# %%
# Try this - Pick a couple of columns and check their type on your own

# %% [markdown]
# ### 2) Do I have missing values?
#
# <a id='missing_check'></a>

# %% [markdown]
# Missing data in the training data set can reduce the power / fit of a model or can lead to a biased model because we have not analysed the behavior and relationship with other variables correctly. It can lead to wrong prediction or classification.

# %% [markdown]
# If we have missing data, is the missing data at random or not? If data is missing at random, the data distribution is still representative of the population. You can probably ignore the missing values as an inconvenience. However, if the data is systematically missing, the analysis you do may be biased. You should carefully consider the best way to clean the data, it may involve dropping some data.

# %% [markdown]
# We want to see how many values are missing in certain variable columns. One way to do this is to count the number of null observations.
#
# For this, we wrote a short function to apply to the dataframe.
#
# We print out the first few observations, but you can remove the .head() to print out all columns.

# %%
#Create a new function:
def num_missing(x):
    return sum(x.isnull())

#Applying per column:
# print("Missing values per column:")
## Check how many are missing by column, and then check which ones have any missing values
# print(df.apply(num_missing, axis=0).where(lambda x : x != 0).dropna()) 
print(kiva_loans.apply(num_missing,axis=0))
#axis=0 defines that function is to be applied on each column
# Out:
# id                        0
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# use                     713
# country_code              0
# country                   0
# region                 8752
# currency                  0
# partner_id             8372
# posted_time               0
# disbursed_time          381
# funded_time            5446
# term_in_months            0
# lender_count              0
# tags                  23186
# borrower_genders        712
# repayment_interval        0
# date                      0
# dtype: int64

# %%
#checking the % of missing values
total = df.isnull().sum().sort_values(ascending = False)

percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending = False)

missing_kiva_loans_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_kiva_loans_data
# Out:
#                        Total   Percent
# funded_date              937  0.155674
# use                      342  0.056820
# description              342  0.056820
# location_country_code     17  0.002824
# sector                     0  0.000000
# repayment_term             0  0.000000
# funded_amount              0  0.000000
# status                     0  0.000000
# lender_count               0  0.000000
# loan_amount                0  0.000000
# id_number                  0  0.000000

# %% [markdown]
# ### 3) Sanity Checks
# <a id='obs_check'></a>

# %% [markdown]
# **Does the dataset match what you expected to find?**
# - is the range of values what you would expect. For example, are all loan_amounts above 0.
# - do you have the number of rows you would expect
# - is your data for the date range what you would expect. For example, is there a strange year in the data like 1880.
# - are there unexpected spikes when you plot the data over time
#
#
# In the command below we find out the number of rows and number of columns by using the function shape. You can also use len(df.index) to find the number of rows.

# %%
print(f'There are {df.shape[0]} observations and {df.shape[1]} features')
# Out:
# There are 6019 observations and 11 features

# %% [markdown]
# Remember, each row is an observation and each column is a potential feature.
#
# Remember we need a large amount of data for machine learning.

# %% [markdown]
# ### 4) Descriptive statistics of the dataset
#
# <a id='desc_stats'></a>

# %%
#Try out - Write code that provides key summary statistics for each numeric column.

# %% [markdown]
# In order to get the same summary statistics for categorical columns (string) we need to do a little data wrangling. The first line of code filters for all columns that are a data type object. As we know from before this means they are considered to be a string. The final row of code provides summary statistics for these character fields.

# %%
categorical = kiva_loans.dtypes[kiva_loans.dtypes == "object"].index
kiva_loans[categorical].describe()
# Out:
#        activity       sector                      use country_code country  \
# count     75825        75825                    75112        75825   75825
# unique      143           15                    38572            1       1
# top     Farming  Agriculture  to buy a solar lantern.           KE   Kenya
# freq      20555        33644                      880        75825   75825
#
#        region currency                posted_time             disbursed_time  \
# count   67073    75825                      75825                      75444
# unique    393        2                      75737                       2375
# top     Kisii      KES  2017-04-27 11:53:12+00:00  2017-02-01 08:00:00+00:00
# freq     3546    75311                          2                       2496
#
#                       funded_time                       tags borrower_genders  \
# count                       70379                      52639            75113
# unique                      63848                      12928             5349
# top     2015-03-18 06:46:14+00:00  #Parent, #Woman Owned Biz           female
# freq                           14                       2977            49719
#
#        repayment_interval        date
# count               75825       75825
# unique                  4        1117
# top               monthly  2016-11-18
# freq                46230         456

# %%
#Try out - What's the other way one can obtain the information above?

# %% [markdown]
# In the table above, there are 4 really useful fields:
#
# 1) **count** - total number of fields populated (Not empty).
#
# 2) **unique** - tells us how many different unique ways this field is populated.
#
# 3) **top** - tells us the most popular data point.
#
# 4) **freq** - tells us that how frequent the most popular category is in our dataset.

# %% [markdown]
# What is next
# -----
#
# In the next section, we move on to exploratory data analysis (EDA).

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
